# %% [markdown]
# <a href="https://colab.research.google.com/github/RSusan-data/Carbon-Emission-Data-Analysis/blob/main/Susen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import openpyxl
aylar = [
         "Yanvar",
         "Fevral",
         "Mart",
         "Aprel",
         "May",
         "Iyun",
         "Iyul",
         "Avqust",
         "Sentyabr",
         "Oktyabr",
         "Noyabr",
         "Dekabr"
]
cari_ay_sirasi =2
# Try reading the file with the 'openpyxl' engine directly
df3 = pd.read_excel("/content/R000.xlsx")
#df2 = pd.read_excel("/content/R002.xlsx")
#df2 = pd.read_excel("/content/Çıxarış_110320250909.xlsx")
# df4 = pd.read_excel("/content/sample_data/2021_4.xlsx")
#df1.drop(index=df1.index[-1],axis=0,inplace=True)
#df2.drop(index=df2.index[-1],axis=0,inplace=True)
#df2.drop(index=df2.index[-1],axis=0,inplace=True)
#df4.drop(index=df4.index[-1],axis=0,inplace=True)
#df3=pd.concat([df,df1,df2,df4])
#df3=pd.concat([df1,df2])
df3 =df3.replace(r'^\s*$',np.nan,regex=True)
df3 = df3.dropna(subset=["Analiz nəticəsi"])
df3.reset_index(drop=True,inplace=True)
df3["cari_ay_sirasi"] = df3["NQA tarixi"].dt.month
df3 = df3[df3["cari_ay_sirasi"]<=cari_ay_sirasi]
df3.reset_index(drop=True,inplace=True)


fitosanitar = ["MƏRKƏZİ FİTOSANİTAR LABORATORİYASI","XAÇMAZ REGİONAL SINAQ LABORATORİYASI","FİTOLAB MSL","MFL MEYVƏLİ KARANTİN EKSPERTİZA BÖLMƏSİ",
               "MƏRKƏZİ FİTOSANİTAR LAB","Mərkəzi Fitosanitar Laboratoriyası","Xaçmaz Regional Sınaq Laboratoriya","Meyvəli Karantin-ekspertiza bölməsi","MEYVƏLI KARANTIN-EKSPERTIZA BÖLMƏSI"]

Qida = ["ABŞERON REGİONAL SINAQ LABORATORİYASI","BAKI REGİONAL SINAQ LABORATORİYASI","MİLLİ REFERENS LABORATORİYASI","MİLLİ REFERENS LAB",
        "ABŞERON RSL","BAKI RSL","Milli Referens Laboratoriyası","Bakı Regional Sınaq Laboratoriyası","Abşeron Regional Sınaq Laboratoriyası",
        "Bakı Regional Sınaq laboratoriyası","MILLI REFERENS LABORATORIYASI",'GƏNCƏ REGİONAL SINAQ LABORATORİYASI']

Baytarliq = ['MBL-NIN BƏRDƏ REGİONAL BÖLMƏSİ',"MƏRKƏZİ BAYTARLIQ LABORATORİYASI","GÖYGÖL REGİONAL SINAQ LABORATORİYASI",
             "MBL-NIN QAX REGİONAL BÖLMƏSİ","MBL-NIN SABİRABAD REGİONAL BÖLMƏSİ","MBL-NIN QUBA REGİONAL BÖLMƏSİ","MƏRKƏZİ BAYTARLIQ LAB","GÖYGÖL RSL",
             "MBL Qax Regional Sınaq Laboratoriya","Mərkəzi Baytarlıq Laboratoriyası","Göygöl  Regional Sınaq Laboratoriya","MBL Quba Regional bölməsi",
             "MBL Sabirabad Regional Sınaq Laboratoriya","MBL Bərdə Regional Bölməsi"]

Kompleks = ["KOMPLEKS TƏDQİQATLAR LABORATORİYASI","KOMPLEKS TƏDQİQATLAR LAB","Kompleks Tədqiqatlar Laboratoriyası","KTL-NIN ŞAMAXI AQROKİMYA BÖLMƏSİ","KOMPLEKS TƏDQIQATLAR LABORATORIYASI","ŞAMAXI REGİANAL SINAQ LABORATORİYASI"]

Qarisiq = ["TOVUZ REGİONAL SINAQ LABORATORİYASI","LƏNKƏRAN REGİONAL SINAQ LABORATORİYASI", "TOVUZ RSL", "LƏNKƏRAN RSL","Tovuz Regional Sınaq Laboratoriya",
           "Lənkəran Regional Sınaq Laboratoriya","TOVUZ  REGIONAL SINAQ LABORATORIYA","LƏNKƏRAN REGİONAL SINAQ LABORATORİYASI"]



kompleks_ = [
               "Aqrokimyəvi maddələrin dövlət sınağı, təkrar qeydiyyatı və ekspertizası",
               "Gübrələr",
               "Pestisidlərin və bioloji preparatların dövlət sınağı, təkrar qeydiyyatı və ekspertizası",
                'Suvarma suyunun analizi',
                'Suvarma suyunda toksikoloji analizlər',"Baytarlıq preparatlarının, yem və yem əlavələrinin istifadə üçün təqdim edilən seriyalarının (partiyalarının) keyfiyyətinin müəyyən edilməsi",
             "Baytarlıq preparatlarının, yem və yem əlavələrinin sınağı, ekspertizası, qeydə alınması",
             "Baytarlıq preparatlarının, yem və yem əlavələrinin aprobasiyası",
                 "Torpaqda toksikoloji analizlər","Torpağın məhsuldarlıq göstəricilərinin təyini","Torpağın kimyəvi göstəricilərinin təyini",
             "Torpağın məhsuldarlıq göstəricilərinin təyini","Torpağın kimyəvi göstəricilərinin təyini","Torpağın fiziki göstəricilərinin təyini",
             "Torpağın aqrokimyəvi kartoqramının hazırlanması","Qablaşdırma materiallarına dair müayinələr","Bioloji aktiv qida məhsulları və qida əlavələrinə dair müayinələr",
               "Bioloji aktiv qida məhsulları və qida əlavələrinə dair müayinələr"
  ]

baytarliq_ = [
                 "Heyvan xəstəliklərinin diaqnostikası",
                 "Yem və yem əlavələri",
                 "Yoluxucu xəstəliklərin siyahısına daxil edilmiş xüsusi təhlükəli heyvan xəstəlikləri istisna olmaqla, digər xəstəliklərin diaqnostikası (müayinəsi)",

                 "Nəzarət analizləri metodikalarının öyrənilməsi üzrə məsləhətlər",
                 "Baytarlıq preparatlarının, yem və yem əlavələrinin sınağı, ekspertizası, qeydə alınması",
                 "Yoluxucu xəstəliklərin siyahısına daxil edilmiş xüsusi təhlükəli heyvan xəstəlikləri istisna olmaqla, digər xəstəliklərin diaqnostikası (müayinəsi)",
                 "Mikrobioloji göstəricilər",
                 "Heyvanların identikləşdirilməsi (kodlaşdırılması)",
                 "Xüsusi təhlükəli heyvan xəstəlikləri istisna olmaqla, digər xəstəliklər nəticəsində ölmüş heyvanların cəsədlərinin zərərsizləşdirilməsi zamanı baytarlıq-sanitariya tədbirləri",
                 "Baytarlıq preparatlarının, yem və yem əlavələrinin aprobasiyası",
                 "Digər","Heyvanların identikləşdirilməsi (kodlaşdırılması)"

  ]

qida_ = [
                 "Qida mikrobiologiyası",
                 "Qida məhsullarının fiziki-kimyəvi göstəriciləri",
                 "Qida məhsullarının toksikologiyası",
                 "Radiologiya",
                 "Molekulyar-biologiya (Polimeraz Zəncirvari Reaksiya)",
         "Heyvan mənşəli məhsulların və xammalın baytarlıq (baytarlıq-sanitariya) ekspertizası",
         "Bitki və bitkiçilik məhsullarının keyfiyyət analizi",
         "Bitki və bitkiçilik məhsullarında toksikoloji analizlər",
         "Qida məhsullarının fiziki-kimyəvi və digər müayinələri",
         "Mikrobioloji müayinələr",
         "Radioloji müayinələr",
         "Molekulyar-bioloji müayinələr",
         "M2.11 Mikrobioloji müayinələr",
         "M2.12 Mikrobioloji müayinələr","Mikrobioloji müayinələr"," Qida məhsullarının fiziki-kimyəvi göstəriciləri-1nümunə",
                 "Qida məhsullarının fiziki-kimyəvi və digər müayinələri","Q1.112Orqanoleptik göstəricilərin təyini","M2.12 Mikrobioloji müayinələr",
                 "Qida məhsullarının fiziki-kimyəvi və digər müayinələri","Q1.200 Qida məhsullarının fiziki-kimyəvi ","Qida məhsullarının fiziki-kimyəvi göstəriciləri ",
                 "Qida məhsullarının fiziki-kimyəvi göstəriciləri"
  ]

fitosanitar_ = [ "Ərzaq və texniki emal təyinatlı bitkiçilik məhsullarında bitkilər üçün zərərli olan orqanizmlərin təyini",
                "Karantin nəzarətində olan bitkilər",
                "Fiziki və hüquqi şəxslərin müraciətləri əsasında fitosanitar karantin baxışının keçirilməsi",
                "Fiziki və hüquqi şəxslərin müraciətləri əsasında fitosanitar müayinəsinin və ekspertizasının aparılması",
                 "Fiziki və hüquqi şəxslərin müraciətləri əsasında fitosanitar karantin baxışının keçirilməsi, müayinəsinin və ekspertizasının aparılması",
                 "Zərərli orqanizmlərin molekulyar-bioloji üsullarla laboratoriya təyini",
                 "Fiziki və hüquqi şəxslərin müraciətləri əsasında fitosanitar müayinəsinin və ekspertizasının aparılması","Zərərli orqanizmlərin molekulyar-bioloji üsullarla laboratoriya təyini",
                 "Fiziki və hüquqi şəxslərin müraciətləri əsasında fitosanitar müayinəsinin və ekspertizasının aparılması",
                 "Fiziki və hüquqi şəxslərin müraciətləri əsasında fitosanitar karantin baxışının keçirilməsi, müayinəsinin və ekspertizasının aparılması"
]

group = []

for index,i in enumerate(df3["Laboratoriya"]):
  if i in fitosanitar:
    group.append("Fitosanitar nəzarət")
  elif i in Qida:
    group.append("Qida təhlükəsizliyi nəzarəti")
  elif i in Kompleks:
    group.append("Kompleks tədqiqatlar")
  elif i in Baytarliq:
    group.append("Baytarlıq nəzarəti")
  elif i in Qarisiq:
    if df3["Analiz qrupu"][index] in fitosanitar_:
      group.append("Fitosanitar nəzarət")
    elif df3["Analiz qrupu"][index] in baytarliq_:
      group.append("Baytarlıq nəzarəti")
    elif df3["Analiz qrupu"][index] in qida_:
      group.append("Qida təhlükəsizliyi nəzarəti")
    else:
      group.append("Digər")
  else:
    group.append("Digər")
df3["analiz_group"] = group

# rub=[]
# for x in df3["cari_ay_sirasi"]:
#   if x in [1,2,3]:
#     rub.append("1-ci rub")
#   elif x in [4,5,6]:
#     rub.append("2-ci rub")
#   elif x in [7,8,9]:
#     rub.append("3-cu rub")
#   elif x in [10,11,12]:
#     rub.append("4-cu rub")
#   else:
#     rub.append("Diger")
# df3["Rüb"]= rub

# for index,i in enumerate(df3["Analiz qrupu"]):
#     if i in fitosanitar:
#         group.append("Fitosanitar nəzarət")
#     elif i in baytarliq:
#         group.append("Baytarlıq nəzarəti")
#     elif i in qida:
#         group.append("Qida təhlükəsizliyi nəzarəti")
#     else:
#         if df3["Analizin tipi"][index]=="Veterinary":
#             group.append("Baytarlıq nəzarəti")
#         elif df3["Analizin tipi"][index]=="Food":
#             group.append("Qida təhlükəsizliyi nəzarəti")
#         elif df3["Analizin tipi"][index]=="Phytosanitary":
#             group.append("Fitosanitar nəzarət")
#         else:
#             group.append(i)



# Numune novleri

# qida_mehsullari = [
# 'Fiziki və hüquqi şəxslərin müraciətləri əsasında fitosanitar müayinəsinin və ekspertizasının aparılması',
# 'Qida məhsullarının fiziki-kimyəvi göstəriciləri',
# 'Qida məhsullarının toksikologiyası',
# 'Qida mikrobiologiyası',
# 'Molekulyar-biologiya (Polimeraz Zəncirvari Reaksiya)',
# 'Bitki və bitkiçilik məhsullarında toksikoloji analizlər',
# 'Radiologiya',
# ]

# qeyri_qida = [
# 'Qablaşdırma materialları',
# ]

# baytarliq_preparati = [
# 'Baytarlıq preparatlarının, yem və yem əlavələrinin istifadə üçün təqdim edilən seriyalarının (partiyalarının) keyfiyyətinin müəyyən edilməsi',
# 'Baytarlıq preparatlarının, yem və yem əlavələrinin sınağı, ekspertizası, qeydə alınması',
# 'Baytarlıq preparatlarının, yem və yem əlavələrinin aprobasiyası'
# ]
# pestesid = [
# 'Pestisidlərin və bioloji preparatların dövlət sınağı, təkrar qeydiyyatı və ekspertizası',
# ''
# ]
# aqro_kimyevi_maddeler = [
# 'Aqrokimyəvi maddələrin dövlət sınağı, təkrar qeydiyyatı və ekspertizası',
# ]

# patoloji = [
# 'Yoluxucu xəstəliklərin siyahısına daxil edilmiş xüsusi təhlükəli heyvan xəstəlikləri istisna olmaqla, digər xəstəliklərin diaqnostikası (müayinəsi)',
# 'Heyvan mənşəli məhsulların və xammalın baytarlıq (baytarlıq-sanitariya) ekspertizası'
# ]

# bfmqe_ve_qe = [
# 'Bioloji Fəallığa malik Qida Əlavələri və Qida Əlavələri',
# 'Bitki mühafizə vasitələrində toksikoloji analizlər'
# ]

# diger = [
#     'Suvarma suyunun analizi',
#       'Suvarma suyunda toksikoloji analizlər'
# ]

# numune_novleri = []

# for i in df3["Analiz qrupu"]:
#     if i in qida_mehsullari:
#         numune_novleri.append("Qida məhsulları ")
#     elif i in qeyri_qida:
#         numune_novleri.append("Qeyri-qida məhsulları")
#     elif i in baytarliq_preparati:
#         numune_novleri.append("Baytarlıq preparatları")
#     elif i in pestesid:
#         numune_novleri.append("Pestesidlər")
#     elif i in aqro_kimyevi_maddeler:
#         numune_novleri.append("Aqro-kimyəvi maddələr")
#     elif i in patoloji:
#         numune_novleri.append("Patmaterial")
#     elif i in bfmqe_ve_qe:
#         numune_novleri.append("Biloji fəallığa malik qida əlavəsi və qida əlavəsi")
#     elif i in diger:
#         numune_novleri.append("Digər")
#     else:
#         numune_novleri.append(i)

# df3["Numune_novleri"] = numune_novleri


# df3["mehsul"] = df3["Məhsul"].apply(lambda x: str(x).lower())

# qeyri_qida_mehsulu = [
#                       "Xurma  tingi",
#                       "LAVANDA",
#                       "Kəsilmiş budaqlar",
#                       "Kəsilmiş yarpaqlar",

# 'Kəsilmiş yarpaqlar', 'Kəsilmiş budaqlar',
# 'Gavalı calaqaltısı',
# 'Gavalı calaqaltısı',
# 'QƏRƏNFIL ŞTILI', 'Çiyələk ştili', 'PALID QOZASI',
# 'Çiyələk ştiliDəniz yosunu', 'Limon tingi',
# 'MEŞƏ MATERIALI (TAXTA)', 'MEŞƏ MATERIALI(TAXTA)', 'TAXTA',
# 'Pambıq lifi', 'PAMBIQ ÇIYIDI', 'PAMBIQ ÇIYIDININ CECƏSI',
# 'PAMBIQ LIFININ TULLANTISI', 'Pambıq toxumu', 'Pambiq yağı',
# 'Pambıq liflərinin tullantıları (əyirmə tullantıları və didilmiş xammal daxil olmaqla',
# 'PAMBIQ LINTI', 'PAMBIQ TIFTIYI', 'Toxumluq kartof',
# 'Qarğıdalı toxumu', 'Buğa toxumu', 'Noxud toxumu',
# 'GÜNƏBAXAN TOXUMU', 'Tütün toxumu', 'YULAF TOXUMU',
# 'RUKOLLA TOXUMU', 'Kələm toxumu', 'İspanaq toxumu', 'TURP TOXUMU',
# 'KASNI TOXUMU', 'YONCA TOXUMU', 'Çim toxumu', 'Badımcan toxumu',
# 'KAHI TOXUMU', 'Çuğundur toxumu', 'Heyvan toxumu', 'Soya toxumu',
# 'TOXUM QARIŞIĞI', 'Ağac toxumları', 'Qarpız toxumu',
# 'Pomidor toxumu', 'YERKÖKÜ TOXUMU', 'Kök toxumu', 'Xiyar toxumu',
# 'Soğan toxumu', 'LOBYA TOXUMU', 'Yemiş toxumu', 'KƏTAN TOXUMU',
# 'Bibər toxumu', 'GÜLKƏLƏM TOXUMU', 'ÇƏLTIK TOXUMU',
# 'KEŞNIŞ TOXUMU', 'CİRƏ TOXUMU', 'Brokkoli toxumu', 'GÜL TOXUMU',
# 'Çia toxumu', 'Bəzək (dekorativ) ağacları və kolları',
# 'Ağac yonqarı', 'Qoz ağacından hazırlanmış yarımfabrikatlar',
# 'Ağac parket', 'Ağac məmulatları', 'Alma Tingləri', 'Tut Tingi',
# 'Əncir Tingi', 'Qoz tingi', 'Üzüm Tingi', 'Badam tingi',
# 'Ərik Tingi', 'Şaftalı Tingi', 'Gilas tingi', 'Gavalı tingi',
# 'AVAKADO TING', 'HEYVA TINGI', 'Kivi tingi', 'Albalı tingi',
# 'Torf', 'Torpaq', 'Pomidor bitkisi yarpaqları', 'Üzüm yarpağı',
# 'Xiyar yarpağı', 'Tütün yarpağı', 'ARMUD TINQI',
# 'Şaftalı Calaqaltısı', 'BADAM CALAQALTISI', 'Gavalı calaqaltısı',
# 'Pomidor şitili', 'Kəsilmiş güllər', 'Qızılgül', 'GÜL TINGI',
# 'Gül soğanağı', 'Palıd parket', 'Toxum', 'Şüyüd toxumu',
# 'SOYA TOXUMUNU', 'PAMBIQ TOXUMU', 'Şəkər çuğunduru toxumu',
# 'Oduncaq talaşası', 'XAM IPƏK (EŞILMƏMIŞ)', 'İPƏK TULLANTISI',
# 'Barama', 'Gilas Сalaqaltısı', 'Fındıq tingi', 'Fındıq qabığı',
# 'SINTETIK IPLIK TULANTISI', 'Karton qutu', 'Karton qutular'
# ]


# numune_novleri2=[]

# for index,i in enumerate(df3["Numune_novleri"]):
#     if (i=="Qida məhsulları") and df3["Məhsul"][index] in qeyri_qida:
#         numune_novleri2.append("Qeyri-qida məhsulları")
#     elif (i =="Qida məhsulları") and "BIOLOJI" in df3["Məhsul"][index]:
#         numune_novleri2.append("Biloji fəallığa malik qida əlavəsi və qida əlavəsi")
#     else:
#         numune_novleri2.append(i)
# df3["Numune_novleri2"]= numune_novleri2

# numune_novleri3 =[]
# for index,i in enumerate(df3["mehsul"]):
#     if ("tingi" in i)| ("toxumu" in i)| ("toxumlar" in i):
#         numune_novleri3.append("Qeyri-qida məhsulları")
#     else:
#         numune_novleri3.append(df3["Numune_novleri2"][index])

# df3["Numune_novleri3"]=numune_novleri3


numunenin_teyinati =[]
for i in df3["Nümunənin təyinatı"]:
    if i in ['İdxal prosesi',
             'İdxal (prosessiz)']:
        numunenin_teyinati.append("İdxal")
    elif i in ['İxrac (prosessiz)',
               'İxrac prosesi',
               'Heyvan məhsulları ixrac']:
        numunenin_teyinati.append("İxrac")
    elif i in ['Monitoring (prosessiz)',
              'Monitorinq',
              'Monitoring']:
        numunenin_teyinati.append("Monitorinq")
    elif i in ['Dövlət sifarişi',
              'Dövlət qurumu',
              'Regional baytarlıq idarəsi']:
        numunenin_teyinati.append("Dövlət qurumu")
    elif i in [ 'Müqavilə üzrə fərdi müraciət',
              'Fərdi müraciət']:
        numunenin_teyinati.append("Fərdi istək")
    elif i in ["Şikayət"]:
        numunenin_teyinati.append("Şikayət")
    elif i in ['Yoxlama (plandan kənar)',
               'Yoxlama (planlı)']:
        numunenin_teyinati.append("Yoxlama")
    # elif i in ["Aqrokimyəvi qeydiyyat"]:
    #     numunenin_teyinati.append("Aqrokimyəvi qeydiyyat")
    # elif i in ["BP qeydiyyatı"]:
    #     numunenin_teyinati.append("BP qeydiyyatı")
    else:
        numunenin_teyinati.append("Digər")

# %%
df3["Numunenin_teyinati"] = numunenin_teyinati

analizin_neticesi = []

for i in df3["Analiz nəticəsi"]:
    if i in ['Uyğun deyil','Karantin Tətbiq edilən','Müsbət','Aşkar edildi']:
        analizin_neticesi.append("Uyğun deyil")
    elif i in ['Uyğundur','Karantin Tətbiq edilməyən','Mənfi','Aşkar edilmədi']:
        analizin_neticesi.append("Uyğundur")
    else:
        analizin_neticesi.append(i)
df3["Analiz nəticəsi"] = analizin_neticesi

# %% [markdown]
# # New Section

# %%
df3=df3[df3["Laboratoriya"]!="FOOD CİTY KOMPLEKS LABORATORİYASI"]
df3=df3[df3["Laboratoriya"]!="AGRO BİTKİ KLİNİKASI"]
df3=df3[df3["Laboratoriya"]!="Agro Bitki Klinikası"]   #silir bu lablari

# %%
df3=pd.concat([df1,df2])
df3 =df3.replace(r'^\s*$',np.nan,regex=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-186/441679484.py in <cell line: 0>()
# ----> 1 df3=pd.concat([df1,df2])
#       2 df3 =df3.replace(r'^\s*$',np.nan,regex=True)
#
# NameError: name 'df1' is not defined

# %%
df5= df3[df3["Analiz qrupu"]=="Digər"]

# %%
df5.to_excel('digər_data.xlsx')

# %%
print(df3.columns)
# Out:
# Index(['Akt nömrəsi', 'Subyektin ID kodu', 'Subyekt', 'İstinad sənəd nömrəsi',
#        'Nümunənin təyinatı', 'Nümunənin təyinatı alt modulu', 'Ölkə', 'Məhsul',
#        'Laboratoriya', 'Region', 'Analizin adı', 'Analiz qrupu', 'Analiz Tipi',
#        'Analiz parametri', 'Nəticə', 'Tətbiq edilən sınaq metodu',
#        'Texniki normativ hüquqi sənəd', 'Analiz nəticəsi', 'NGA tarixi',
#        'NQA tarixi', 'Analizin başlama tarixi', 'Analizin bitmə tarixi',
#        'Laboratoriya göndərilmə tarixi', 'Regional bölməyə göndərilmə tarixi',
#        'Status', 'Müraciət növü', 'Əmtəə nişanı', 'Qiymət',
#        'Elmi Araşdırma Mərkəzi tərəfindən qeyd olunan rəy', 'XIF MN kodu',
#        'Ərizənin təyinatı', 'Ödəniş statusu', 'cari_ay_sirasi', 'analiz_group',
#        'Numunenin_teyinati'],
#       dtype='object')

# %%
df3=df3[df3["Analiz qrupu"]!="Digər"]

# %%
import pandas as pd
from IPython.display import display
import datetime
from google.colab import files

# Pivot cədvəlin yaradılması
analiz = pd.pivot_table(
    df3,
    index=["Analiz Tipi"],
    columns=["Analiz nəticəsi"],
    values="Akt nömrəsi",
    aggfunc=len
)

# Indexi sıfırlayıb, NaN-ları 0 ilə doldurmaq
analiz = analiz.reset_index()
analiz = analiz.fillna(0)

# Pivotu Colab-da göstərmək
display(analiz)

# Pivotu Excel-ə yazmaq
ay_indeksi = datetime.datetime.today().month - 2  # keçən ay
fayl_adi = f'analiz_2025_{aylar[cari_ay_sirasi-1]}.xlsx'
analiz.to_excel(fayl_adi, index=False)

# Excel faylını endirmək
files.download(fayl_adi)
# Out:
# Analiz nəticəsi           Analiz Tipi  Faktiki  Uyğun deyil  Uyğundur
# 0                           Baytarlıq    309.0       2232.0   13075.0
# 1                         Fitosanitar      0.0         88.0    8747.0
# 2                Kompleks tədqiqatlar   1204.0        105.0    4350.0
# 3                                Qida  15518.0        294.0   44398.0

# %%
pivot12 = pd.pivot_table(df3,index=["Analiz Tipi"],
                      columns=["cari_ay_sirasi"],
                       values = "Akt nömrəsi",
                      aggfunc=len)
pivot12 = pivot12.reset_index()
pivot12 =pivot12.fillna(0)
pivot12.to_excel(f'2022_nezaret_sahesi_aylar{aylar[datetime.datetime.today().month-2]}.xlsx')
pivot12

fayl_adi = f'2025_nezaret_sahesi_aylar{aylar[datetime.datetime.today().month-2]}.xlsx'
pivot12.to_excel(fayl_adi, index=False)
files.download(fayl_adi)
